# %%
import pandas as pd

# %%
df=pd.read_csv("./train_test_practice_data.csv")
df.head(1)
# Out:
#   student_id  study_hours_per_week  attendance_rate  previous_grade  \
# 0   STD_1000                  10.7             98.0            56.9
#
#    tutoring_sessions  sleep_hours_per_night parental_education  \
# 0                  2                    6.4           Bachelor
#
#   internet_access  exam_score  passed_exam
# 0             Yes        62.0            0

# %%
X=df[["study_hours_per_week","previous_grade","tutoring_sessions"]]
y=df["passed_exam"]

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'
